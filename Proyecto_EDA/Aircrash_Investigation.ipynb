# %% [markdown]
# #  <p style="text-align: center;">AIRCRASH INVESTIGATION</p>

# %% [markdown]
# # FUENTES
#
# ### Kaggle:
#
# MihirSethi
# Hay dos datasets aparentemente iguales, hay que mirarlos bien y decidir cuál tiene los datos más completos
# dataset1: Airplane_Crashes_and_Fatalities_Since_1908.csv
# dataset2: aircrash1908-2008.csv
# link: 'https://www.kaggle.com/mihirsethi007/aircrash-data'
# ***Fuente Principal***
# Descripción: Datos de accidentes desde 1908.
#
# *mirar: Código interesante*: https://www.kaggle.com/mihirsethi007/fork-of-air-crash-analysis-1908-2009
#
# ### planecrashinfo.com:
# Richard Kebabjian
# dataset: web scrapping
# link: 'http://www.planecrashinfo.com/database.htm'
# ***Fuente Complementaria***
# Descripción: Datos de accidentes desde 1908, tiene datos diversos, parece ser la fuente desde la que se hizo el dataset de Kaggle. En las tablas de la web no están todos los campos, sin embargo tiene url's con datos agregados por tipo de accidente y otras variables.
#
# ### datos.bancomundial.org:
#
# Organización de Aviación Civil Internacional (OACI)
# dataset: API_IS.AIR.DPRT_DS2_es_csv_v2_2169474.csv
# link: 'https://datos.bancomundial.org/indicator/IS.AIR.DPRT'
# ***Fuente Complementaria***
# Descripción: Número de vuelos por país y año desde 1970 hasta 2019, interesante para comparar accidentes con número total de vuelos
#
# ### Airfleets:
#
# Airfleets.net
# dataset: web scrapping
# link: https://www.airfleets.es/crash
# ***Fuente Complementaria***
# Descripción: Datos de vuelos con fecha, compañía aérea, modelo de avión, ciudad de origen, país de origen y número de víctimas. Los datos están normalizados. Interesante para análisis por compañía y modelo de avión.
#
# ### elperiodico:
#
# Graphic News
# dataset: web image
# link:https://www.elperiodico.com/es/extra/20160914/loteria-probabilidad-primitiva-sorteos-5377677
# ***Fuente Secundaria***
# Descripción: Lista de probabilidades de que toquen las diferentes loterías.
#
#
# ### Otras fuentes de consulta:
# https://www.tendenciashoy.com/transportes/siete-aeropuertos-no-aptos-para-miedosos_636098_102.html
#
# https://www.abc.es/viajar/nieve/abci-15-paises-mas-altitud-media-mundo-201702162006_noticia.html
#
# USA: https://es.wikipedia.org/wiki/Estados_montañosos
#
# https://es.gizmodo.com/20-pistas-de-aterrizaje-terrorificas-que-te-quitaran-la-360923120

# %% [markdown]
# # LIBRERÍAS:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import urllib.request
from bs4 import BeautifulSoup

# %%
import warnings
warnings.filterwarnings("ignore")
plt.style.use('seaborn-bright')

# %% [markdown]
# ## HIPÓTESIS PLANTEADAS:
#
# #### Principal:
#
# - La probabilidad de tener un accidente aéreo cambia significativamente en función del **país de destino**, el factor más determinante es la existencia de zonas montañosas en (o cerca) de los aeropuertos.
#
#
# #### Otras hipótesis para intentar resolver:
# - La mayor causa de accidente es el error humano.
# - Las compañías aéreas más seguras del mundo están en Oceanía
# - Las compañías aéreas menos seguras del mundo están en Asia
# - Los fabricantes de aviones más seguros están en Europa
# - Los fabricantes de aviones menos seguros están en Antigua URSS
# - El modelo de avión con más accidentes es el Boeing 737
# - Los vuelos nocturnos son más peligrosos que los diurnos
# - Es más probable que te toque la lotería a tener un accidente de avión
# - Los vuelos militares (en periodo de paz) son más peligrosos que los comerciales
# - El año que tuvo más atentados fue 2001
# - Es más probable tener un accidente provocado por un rayo que por un fallo de diseño del avión.
#
#
# **NOTA:** Estas son hipótesis iniciales. Podrá incorporarse alguna más durante el proceso.
# Para la hipótesis principal será necesario acceder a diferentes fuentes de datos, si no fueva viable una resolución fiable, iteraré hacia otra hipótesis principal.

# %% [markdown]
# ## ANÁLISIS PREVIO DATASET KAGGLE

# %%
air = pd.read_csv('data/Airplane_Crashes_and_Fatalities_Since_1908.csv')

# %%
air.head()
# Out:
#          Date   Time                            Location  \
# 0  09/17/1908  17:18                 Fort Myer, Virginia
# 1  07/12/1912  06:30             AtlantiCity, New Jersey
# 2  08/06/1913    NaN  Victoria, British Columbia, Canada
# 3  09/09/1913  18:30                  Over the North Sea
# 4  10/17/1913  10:30          Near Johannisthal, Germany
#
#                  Operator Flight #          Route                    Type  \
# 0    Military - U.S. Army      NaN  Demonstration        Wright Flyer III
# 1    Military - U.S. Navy      NaN    Test flight               Dirigible
# 2                 Private        -            NaN        Curtiss seaplane
# 3  Military - German Navy      NaN            NaN  Zeppelin L-1 (airship)
# 4  Military - German Navy      NaN            NaN  Zeppelin L-2 (airship)
#
#   Registration cn/In  Aboard  Fatalities  Ground  \
# 0          NaN     1     2.0         1.0     0.0
# 1          NaN   NaN     5.0         5.0     0.0
# 2          NaN   NaN     1.0         1.0     0.0
# 3          NaN   NaN    20.0        14.0     0.0
# 4          NaN   NaN    30.0        30.0     0.0
#
#                                              Summary
# 0  During a demonstration flight, a U.S. Army fly...
# 1  First U.S. dirigible Akron exploded just offsh...
# 2  The first fatal airplane accident in Canada oc...
# 3  The airship flew into a thunderstorm and encou...
# 4  Hydrogen gas which was being vented was sucked...

# %%
air.columns
# Out:
# Index(['Date', 'Time', 'Location', 'Operator', 'Flight #', 'Route', 'Type',
#        'Registration', 'cn/In', 'Aboard', 'Fatalities', 'Ground', 'Summary'],
#       dtype='object')

# %% [markdown]
# ### Variable Notes:
#
# - **Date**:	 Date of accident,  in the format - January 01, 2001
# - **Time**:	 Local time, in 24 hr. format unless otherwise specified
# - **Location**:	 Region and/or Country where the accident took place
# - **Operator:**	 Airline or operator of the aircraft
# - **Flight #:**	 Flight number assigned by the aircraft operator
# - **Route:**	 Complete or partial route flown prior to the accident
# - **Type:**	 Aircraft type
# - **Registration**	 ICAO registration of the aircraft
# - **cn/In:**	 Construction or serial number / Line or fuselage number
# - **Aboard:**	 Total aboard (passengers / crew)
# - **Fatalities:**	 Total fatalities aboard (passengers / crew)
# - **Ground:**	 Total killed on the ground
# - **Summary**	 Brief description of the accident and cause if known

# %%
#Cambio el nombre de una columna para que no haya espacios ni caracteres especiales
air.rename(columns={'Flight #':'nFlight'},
                        inplace = True)

# %%
air.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5268 entries, 0 to 5267
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          5268 non-null   object
#  1   Time          3049 non-null   object
#  2   Location      5248 non-null   object
#  3   Operator      5250 non-null   object
#  4   nFlight       1069 non-null   object
#  5   Route         3562 non-null   object
#  6   Type          5241 non-null   object
#  7   Registration  4933 non-null   object
#  8   cn/In         4040 non-null   object
#  9   Aboard        5246 non-null   float64
#  10  Fatalities    5256 non-null   float64
#  11  Ground        5246 non-null   float64
#  12  Summary       4878 non-null   object
# dtypes: float64(3), object(10)
# memory usage: 535.2+ KB

# %%
air.isna().sum()
# Out:
# Date               0
# Time            2219
# Location          20
# Operator          18
# nFlight         4199
# Route           1706
# Type              27
# Registration     335
# cn/In           1228
# Aboard            22
# Fatalities        12
# Ground            22
# Summary          390
# dtype: int64

# %%
air['unos'] = 1

# %%
# Me deshago de los Nans en todas las variables categóricas y las que tienen valores 
#múltiples, no numéricos, que no aportan info al análisis
lista = ['Time','Location','Operator','nFlight','Route','Type','Registration','cn/In',
         'Summary']
for campo in lista:
    
    air[campo].fillna('Unknown', inplace = True)

# %%
air.groupby('Date')[['unos']].sum().sort_values('unos',ascending = False).head(10)
# Out:
#             unos
# Date
# 09/11/2001     4
# 08/31/1988     4
# 08/27/1992     4
# 02/28/1973     4
# 06/18/1972     4
# 08/28/1976     4
# 11/23/1962     3
# 03/23/1994     3
# 11/15/1934     3
# 05/13/1957     3

# %%
air.groupby('Time')[['unos']].sum().sort_values('unos',ascending = False).head()
# Out:
#        unos
# Time
# 15:00    32
# 12:00    31
# 11:00    29
# 19:30    26
# 16:00    26

# %%
#Analizo el campo Time según su length.
air['len_time'] = air['Time'].str.len()

# %%
#Solamente hay unos pocos que tienen length diferente, los observo y los corrijo
air.groupby('len_time')[['unos']].sum().sort_values('unos',ascending = False)#.head(10)
# Out:
#           unos
# len_time
# 5.0       3033
# 4.0          7
# 7.0          6
# 6.0          3

# %%
air.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5268 entries, 0 to 5267
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          5268 non-null   object
#  1   Time          5268 non-null   object
#  2   Location      5248 non-null   object
#  3   Operator      5250 non-null   object
#  4   nFlight       1069 non-null   object
#  5   Route         3562 non-null   object
#  6   Type          5241 non-null   object
#  7   Registration  4933 non-null   object
#  8   cn/In         4040 non-null   object
#  9   Aboard        5246 non-null   float64
#  10  Fatalities    5256 non-null   float64
#  11  Ground        5246 non-null   float64
#  12  Summary       4878 non-null   object
#  13  unos          5268 non-null   int64
#  14  len_time      5268 non-null   int64
# dtypes: float64(3), int64(2), object(10)
# memory usage: 617.5+ KB

# %%
air.loc[air['len_time']> 5,['Time']]
# Out:
#          Time
# 190   c: 1:00
# 213   c:17:00
# 228   c: 2:00
# 279   c:09:00
# 1462   c16:50
# 2599  c:09:00
# 3267   114:20
# 3390   c14:30
# 4838  c: 9:40

# %%
air['Time'] = air['Time'].map(lambda x: str(x).replace(' ','').replace('c:','').replace('c',''))
air['len_time'] = air['Time'].str.len()

# %%
air.loc[air['len_time']> 5,['Time']].groupby('Time').count()
# Out:
# Empty DataFrame
# Columns: []
# Index: [Unknown]

# %%
air.loc[3267,'Time'] = air.loc[3267,'Time'][1:]
air['len_time'] = air['Time'].str.len()

# %%
air.loc[3267,'Time']
# Out:
# '14:20'

# %%
air['len_time'] = air['Time'].str.len()
air.loc[air['len_time']<5,['Time']]
# Out:
#       Time
# 711   1:30
# 3536  0943
# 3584  1:00
# 4298  2:40
# 4848  2:00
# 4849  8:02
# 5156  9:30

# %%
air.loc[3536,'Time'] = '09:43'
air['len_time'] = air['Time'].str.len()

# %%
air.loc[air['len_time']<5,['Time']]
# Out:
#       Time
# 190   1:00
# 228   2:00
# 711   1:30
# 3584  1:00
# 4298  2:40
# 4838  9:40
# 4848  2:00
# 4849  8:02
# 5156  9:30

# %%
air.loc[air['len_time']== 4,['Time']] = '0' + air.loc[air['len_time']==4,['Time']]
air['len_time'] = air['Time'].str.len()

# %%
air.loc[air['len_time']<5,['Time']]
# Out:
# Empty DataFrame
# Columns: [Time]
# Index: []

# %%
air.groupby('Time')[['unos']].sum().sort_values('unos',ascending = False)#.head(10)
# Out:
#          unos
# Time
# Unknown  2219
# 15:00      32
# 12:00      31
# 11:00      29
# 19:30      26
# ...       ...
# 13:28       1
# 13:26       1
# 13:24       1
# 13:22       1
# 14:47       1
#
# [991 rows x 1 columns]

# %%
air.groupby('Route')[['unos']].sum().sort_values('unos',ascending = False).head(10)
# Out:
#                             unos
# Route
# Unknown                     1706
# Training                      81
# Sightseeing                   29
# Test flight                   17
# Test                           6
# Sao Paulo - Rio de Janeiro     5
# Villavicencio - Mitu           4
# Bogota - Barranquilla          4
# Saigon - Paris                 4
# Sao Paulo - Porto Alegre       4

# %%
separate = air["Route"].str.split(" - ", n=-1, expand=True)
separate
# Out:
#                           0                  1     2     3     4
# 0             Demonstration               None  None  None  None
# 1               Test flight               None  None  None  None
# 2                   Unknown               None  None  None  None
# 3                   Unknown               None  None  None  None
# 4                   Unknown               None  None  None  None
# ...                     ...                ...   ...   ...   ...
# 5263                Jakarta             Maduin  None  None  None
# 5264                   Goma              Isiro  None  None  None
# 5265         Rio de Janeiro              Paris  None  None  None
# 5266  Lourdes de BlanSablon  Port Hope Simpson  None  None  None
# 5267     Mechuka for Jorhat               None  None  None  None
#
# [5268 rows x 5 columns]

# %%
separate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5268 entries, 0 to 5267
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       5268 non-null   object
#  1   1       3339 non-null   object
#  2   2       257 non-null    object
#  3   3       49 non-null     object
#  4   4       11 non-null     object
# dtypes: object(5)
# memory usage: 205.9+ KB

# %%
# count de registros que en Location tienen 'origen - destino'
air['Route'].isnull().sum()
# Out:
# 1706

# %%
separate.rename(columns = {0:'cero',1:'uno',2:'dos',3:'tres',4:'cuatro'}, inplace = True)

# %%
separate.groupby('uno').sum()
# Out:
#                                                      cero
# uno
#                                               PerthBetong
#  Algiers                                       Casablanca
#  Atlanta                                           Dallas
#  Buenos Aires                                Rio Gallegos
#  Honolulu                                         El Toro
# ...                                                   ...
# aerial survelliance                               Jakarta
# de Janerio                                            Rio
# demobilization camp                                Luanda
# drilling rig Golbal Sante Fe Monach  Gas platform Clipper
# Îles-de-la-Madeleine                                Gaspé
#
# [2030 rows x 1 columns]

# %%
# Los Nans de Route los paso a 'Unknown'
air['Route'].fillna('Unknown', inplace = True)

# %%
air[air['Route'].str.contains('-')]
# Out:
#             Date     Time                                           Location  \
# 56    09/06/1921  Unknown                                      Paris, France
# 80    12/23/1923    02:30                         Over the Mediterranean Sea
# 83    04/24/1924  Unknown                           Over the English Channel
# 96    09/03/1925    05:30                                     Caldwell, Ohio
# 102   07/03/1926  Unknown                          Rossaugpt, Czechoslovakia
# ...          ...      ...                                                ...
# 5261  04/29/2009    06:00                 Massamba, DemocratiRepubliof Congo
# 5263  05/20/2009    06:30                             Near Madiun, Indonesia
# 5264  05/26/2009  Unknown                  Near Isiro, DemocratiRepubliCongo
# 5265  06/01/2009    00:15  AtlantiOcean, 570 miles northeast of Natal, Br...
# 5266  06/07/2009    08:30       Near Port Hope Simpson, Newfoundland, Canada
#
#                                              Operator nFlight  \
# 56                                    Franco-Roumaine     NaN
# 80                             Military - French Navy     NaN
# 83                           KLM Royal Dutch Airlines     NaN
# 96                               Military - U.S. Navy     NaN
# 102   Compagnie Internationale de Navigation Aérienne     NaN
# ...                                               ...     ...
# 5261                                         Bako Air     NaN
# 5263                  Military - Indonesian Air Force     NaN
# 5264                                      Service Air     NaN
# 5265                                       Air France     447
# 5266                                       Strait Air     NaN
#
#                                                   Route  \
# 56                        Varsovie - Strasbourg - Paris
# 80                                     Toulon - Algiers
# 83         Lympne, England - Rotterdam, The Netherlands
# 96                        Lakehurst, NJ - S.t Louis, MO
# 102                                      Paris - Prague
# ...                                                 ...
# 5261  Bangui, CAR- Brazzaville, Congo - Harare, Zimb...
# 5263                                   Jakarta - Maduin
# 5264                                       Goma - Isiro
# 5265                             Rio de Janeiro - Paris
# 5266          Lourdes de BlanSablon - Port Hope Simpson
#
#                                      Type Registration      cn/In  Aboard  \
# 56                               Potez IX       F-ADCD        160     5.0
# 80            Zeppelin Dixmunde (airship)         L-72        NaN    52.0
# 83                           Fokker F.III       H-NABS       1535     3.0
# 96    Dirigible ZR-1 Shenandoah (airship)         ZR-1        NaN    43.0
# 102                          Caudron C-61       F-AFBT       5307     7.0
# ...                                   ...          ...        ...     ...
# 5261                     Boeing B-737-200      TL-ADM   22264/753     7.0
# 5263              Lockheed C-130 Hercules       A-1325       1982   112.0
# 5264                        Antonov An-26       9Q-CSA       5005     4.0
# 5265                      Airbus A330-203       F-GZCP        660   228.0
# 5266     Britten-Norman BN-2A-27 Islander      C-FJJR         424     1.0
#
#       Fatalities  Ground                                            Summary  \
# 56           5.0     0.0  Crashed while making an approach to Le Bourget...
# 80          52.0     0.0  Crashed while on a flight from Toulon, France ...
# 83           3.0     0.0                                                NaN
# 96          14.0     0.0  The Shenandoah was flying over Southern Ohio w...
# 102          7.0     0.0                            Crashed while en route.
# ...          ...     ...                                                ...
# 5261         7.0     0.0  Crashed while en route on a ferrying flight. T...
# 5263        98.0     2.0  While on approach, the military transport cras...
# 5264         4.0     NaN  The cargo plane crashed while on approach to I...
# 5265       228.0     0.0  The Airbus went missing over the AtlantiOcean ...
# 5266         1.0     0.0  The air ambulance crashed into hills while att...
#
#       unos  len_time
# 56       1         7
# 80       1         5
# 83       1         7
# 96       1         5
# 102      1         7
# ...    ...       ...
# 5261     1         5
# 5263     1         5
# 5264     1         7
# 5265     1         5
# 5266     1         5
#
# [3362 rows x 15 columns]

# %%
air.groupby('Location')[['unos']].sum().sort_values('unos',ascending = False)
# Out:
#                                unos
# Location
# Moscow, Russia                   15
# Sao Paulo, Brazil                15
# Rio de Janeiro, Brazil           14
# Manila, Philippines              13
# Anchorage, Alaska                13
# ...                             ...
# Mannheim, Germany                 1
# Manta, Ecuador                    1
# Manus Island, New Guinea          1
# Manzanares, Colombia              1
# near Orillia, Ontario, Canada     1
#
# [4303 rows x 1 columns]

# %%
#SEPARO LOS VALORES DE LOCATION PARA CONSEGUIR UNA COLUMNA CON LOS PAISES
separado = air["Location"].str.split(",", n=-1, expand=True)
separado
# Out:
#                                0                              1        2     3
# 0                      Fort Myer                       Virginia     None  None
# 1                    AtlantiCity                     New Jersey     None  None
# 2                       Victoria               British Columbia   Canada  None
# 3             Over the North Sea                           None     None  None
# 4              Near Johannisthal                        Germany     None  None
# ...                          ...                            ...      ...   ...
# 5263                 Near Madiun                      Indonesia     None  None
# 5264                  Near Isiro          DemocratiRepubliCongo     None  None
# 5265                AtlantiOcean   570 miles northeast of Natal   Brazil  None
# 5266      Near Port Hope Simpson                   Newfoundland   Canada  None
# 5267  State of Arunachal Pradesh                          India     None  None
#
# [5268 rows x 4 columns]

# %%
air.groupby('Operator')[['unos']].sum().sort_values('unos',ascending = False)#.head(10)
# Out:
#                            unos
# Operator
# Aeroflot                    179
# Military - U.S. Air Force   176
# Air France                   70
# Deutsche Lufthansa           65
# United Air Lines             44
# ...                         ...
# Everest Air                   1
# Europe Aero Service EAS       1
# Eurojet Italila               1
# Euroair                       1
# de Havilland Aircraft         1
#
# [2476 rows x 1 columns]

# %%
air.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5268 entries, 0 to 5267
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          5268 non-null   object
#  1   Time          5268 non-null   object
#  2   Location      5268 non-null   object
#  3   Operator      5268 non-null   object
#  4   nFlight       5268 non-null   object
#  5   Route         5268 non-null   object
#  6   Type          5268 non-null   object
#  7   Registration  5268 non-null   object
#  8   cn/In         5268 non-null   object
#  9   Aboard        5246 non-null   float64
#  10  Fatalities    5256 non-null   float64
#  11  Ground        5246 non-null   float64
#  12  Summary       5268 non-null   object
#  13  unos          5268 non-null   int64
# dtypes: float64(3), int64(1), object(10)
# memory usage: 576.3+ KB

# %%
air.groupby('Type')[['unos']].sum().sum()#.sort_values('unos',ascending = False).head(50)
# Out:
# unos    5268
# dtype: int64

# %% [markdown]
# # VARIABLES NUMÉRICAS

# %%
air.describe()
# Out:
#             Aboard   Fatalities       Ground    unos     len_time
# count  5246.000000  5256.000000  5246.000000  5268.0  5268.000000
# mean     27.554518    20.068303     1.608845     1.0     5.842445
# std      43.076711    33.199952    53.987827     0.0     0.987604
# min       0.000000     0.000000     0.000000     1.0     5.000000
# 25%       5.000000     3.000000     0.000000     1.0     5.000000
# 50%      13.000000     9.000000     0.000000     1.0     5.000000
# 75%      30.000000    23.000000     0.000000     1.0     7.000000
# max     644.000000   583.000000  2750.000000     1.0     7.000000

# %%
air[air['Ground']==2750]
# Out:
#             Date   Time                 Location           Operator nFlight  \
# 4803  09/11/2001  08:47  New York City, New York  American Airlines      11
# 4804  09/11/2001  09:03  New York City, New York   United Air Lines     175
#
#                      Route              Type Registration      cn/In  Aboard  \
# 4803  Boston - Los Angeles  Boeing 767-223ER       N334AA  22332/169    92.0
# 4804  Boston - Los Angeles  Boeing B-767-222       N612UA   21873/41    65.0
#
#       Fatalities  Ground                                            Summary  \
# 4803        92.0  2750.0  The aircraft was hijacked shortly after it lef...
# 4804        65.0  2750.0  The aircraft was hijacked shortly after it lef...
#
#       unos  len_time
# 4803     1         5
# 4804     1         5

# %%
airno11s = air[air['Ground']<2750]
airno11s.describe()
# Out:
#             Aboard   Fatalities       Ground    unos     len_time
# count  5234.000000  5244.000000  5244.000000  5244.0  5244.000000
# mean     27.569736    20.067315     0.560641     1.0     5.839054
# std      43.105573    33.212478     5.768364     0.0     0.987057
# min       0.000000     0.000000     0.000000     1.0     5.000000
# 25%       5.000000     3.000000     0.000000     1.0     5.000000
# 50%      13.000000     9.000000     0.000000     1.0     5.000000
# 75%      30.000000    23.000000     0.000000     1.0     7.000000
# max     644.000000   583.000000   225.000000     1.0     7.000000

# %%
air[air['Ground']<225].sort_values('Ground',ascending = False)
# Out:
#             Date     Time                           Location  \
# 4802  09/11/2001    09:45               Arlington, Virginia.
# 2933  10/13/1976  Unknown                Santa Cruz, Bolivia
# 2091  12/24/1966    19:15        Binh Tahi, Da Nang, Vietnam
# 1833  02/01/1963    17:15                     Ankara, Turkey
# 4875  07/27/2002    12:45                      Lviv, Ukraine
# ...          ...      ...                                ...
# 1793  08/01/1962    13:15              Near Kathmandu, Nepal
# 1792  07/30/1962  Unknown                Coulommiers, France
# 1791  07/28/1962  Unknown                      Sochi, Russia
# 1790  07/22/1962    23:19                   Honolulu, Hawaii
# 5267  06/08/2009  Unknown  State of Arunachal Pradesh, India
#
#                                                Operator  nFlight  \
# 4802                                  American Airlines       77
# 2933                              Lloyd Aéreo Boliviano  Unknown
# 2091                                  Flying Tiger Line  Unknown
# 1833  Middle East Airlines / Military - Turkish Air ...      265
# 4875                       Military - Ukraine Air Force  Unknown
# ...                                                 ...      ...
# 1793                               Royal Nepal Airlines  Unknown
# 1792                                         Air France  Unknown
# 1791                                           Aeroflot  Unknown
# 1790                           Canadian PacifiAir Lines      323
# 5267                        Military - Indian Air Force  Unknown
#
#                               Route                   Type Registration  \
# 4802  Washington D.C. - Los Angeles       Boeing B-757-223       N644AA
# 2933              Santa Cruz - Viru        Boeing B-707-31       N730JP
# 2091                        Unknown     Canadair CL-44D4-1       N228SW
# 1833               Nicosia - Ankara  Vickers Viscount 754D       OD-ADE
# 4875                        Unknown           Sukhoi Su-27           42
# ...                             ...                    ...          ...
# 1793            Katmandu - New Deli           Douglas DC-3       9N-AAH
# 1792                       Training           Douglas DC-3       F-BAOE
# 1791                        Unknown         Antonov An-10A   CCCP-11186
# 1790          Honolulu - Nadi, Fiji  Bristol Britannia 314       CF-CZB
# 5267             Mechuka for Jorhat          Antonov An-32      Unknown
#
#           cn/In  Aboard  Fatalities  Ground  \
# 4802  24602/365    64.0        64.0   125.0
# 2933   17671/48     3.0         3.0   113.0
# 2091         31     4.0         4.0   107.0
# 1833        244    17.0        17.0    87.0
# 4875    Unknown     2.0         0.0    85.0
# ...         ...     ...         ...     ...
# 1793       6216    10.0        10.0     0.0
# 1792      11769     8.0         4.0     0.0
# 1791    0402003    81.0        81.0     0.0
# 1790      13394    40.0        27.0     0.0
# 5267    Unknown    13.0        13.0     0.0
#
#                                                 Summary  unos  len_time
# 4802  The aircraft was hijacked after taking off fro...     1         5
# 2933  The aircraft failed to climb and crashed into ...     1         7
# 2091  The cargo plane undershot runway by 1 mile whi...     1         5
# 1833  Midair collision between a civilian and milita...     1         5
# 4875  The Su-76 was performing aerobatics when it cr...     1         5
# ...                                                 ...   ...       ...
# 1793  Crashed into a 11,200 ft. mountain, 100 miles ...     1         5
# 1792                  Crashed during a training flight.     1         7
# 1791  Struck a mountain while attempting to land. Ch...     1         7
# 1790  Shortly after takeoff, a fire warning indicati...     1         5
# 5267  The military transport went missing while en r...     1         7
#
# [5243 rows x 15 columns]

# %%
'''
Para evaluar si voy a poder incluir hipótesis relativas a la causa del accidente,
hago un diccionario y una lista con las causas, por si lo puedo usar después.
La fuente es una url dentro del propio planecrahsinfo: 
http://www.planecrashinfo.com/cause.htm
'''

#Causas de accidente en un diccionario
dicausa = {'PILOT ERROR':['Improper procedure', 'Flying VFR into IFR conditions',
                          'Controlled flight into terrain','Descending below minima',
                          'Spatial disorientation', 'Premature descent','Excessive landing speed',
                          'Missed runway','Fuel starvation','Navigation error',
                          'Wrong runway takeoff/landing','Midair collision caused by primary pilot'],
           'MECHANICIAL':['Engine failure','Equipment failure','Structural failure','Design flaw'],
           'WEATHER':['Severe turbulence','Windshear','Mountain wave','Poor visibility','Heavy rain',
                      'Severe winds','Icing','Thunderstorms','Lightning strike'],
           'SABOTAGE':['Hijacking','Shot down','Explosive device aboard','Pilot suicide'],
           'OTHER':['ATC error','Ground crew error','Overloaded','Improperly loaded cargo',
                    'Bird strike','Fuel contamination','Pilot incapacitation','Obstruction on runway',
                    'Midair collision caused by other aircraft',
                    'Fire/smoke in flight (cabin, cockpit, cargo hold)','Maintenance error']
          }

listcausa = ['Improper procedure', 'Flying VFR into IFR conditions',
             'Controlled flight into terrain','Descending below minima',
             'Spatial disorientation', 'Premature descent','Excessive landing speed',
             'Missed runway','Fuel starvation','Navigation error',
             'Wrong runway takeoff/landing','Midair collision caused by primary pilot',
             'Engine failure','Equipment failure','Structural failure','Design flaw',
             'Severe turbulence','Windshear','Mountain wave','Poor visibility','Heavy rain',
             'Severe winds','Icing','Thunderstorms','Lightning strike',
             'Hijacking','Shot down','Explosive device aboard','Pilot suicide',
             'ATC error','Ground crew error','Overloaded','Improperly loaded cargo',
             'Bird strike','Fuel contamination','Pilot incapacitation','Obstruction on runway',
             'Midair collision caused by other aircraft',
             'Fire/smoke in flight (cabin, cockpit, cargo hold)','Maintenance error']

# %%
#busco los valores de la lista de causas en el campo 'Summary'
air['sum2'] = 0

for causa in listcausa:
    
    air.loc[air['Summary'].str.contains(causa),'sum2'] = causa

# %%
#Dado que es un campo con texto sin reglas, encuentro solamente
#325 registros en los que está el texto literal, por lo que no me va a servir
#para hacer este análisis.
air.groupby('sum2')[['unos']].sum()#.sum()
# Out:
#                                 unos
# sum2
# 0                               4943
# ATC error                          8
# Controlled flight into terrain     6
# Design flaw                        1
# Engine failure                    51
# Fuel contamination                 6
# Fuel starvation                   19
# Heavy rain                         1
# Hijacking                          3
# Icing                             37
# Improper procedure                 4
# Improperly loaded cargo            2
# Maintenance error                  2
# Navigation error                  13
# Overloaded                        21
# Poor visibility                    5
# Premature descent                 10
# Severe turbulence                  3
# Severe winds                       1
# Shot down                         95
# Spatial disorientation            12
# Structural failure                 7
# Thunderstorms                      1
# Windshear                         17

# %%
#Hago una copia del df 'air' para trabajar sobre la copia, voy a quitar NaNs para
#poder trabajar con búsquedas de strings usando str.
air2 = air.copy()

# %%
air2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5268 entries, 0 to 5267
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          5268 non-null   object
#  1   Time          3049 non-null   object
#  2   Location      5268 non-null   object
#  3   Operator      5250 non-null   object
#  4   nFlight       1069 non-null   object
#  5   Route         3562 non-null   object
#  6   Type          5241 non-null   object
#  7   Registration  4933 non-null   object
#  8   cn/In         4040 non-null   object
#  9   Aboard        5246 non-null   float64
#  10  Fatalities    5256 non-null   float64
#  11  Ground        5246 non-null   float64
#  12  Summary       5268 non-null   object
#  13  unos          5268 non-null   int64
#  14  sum2          5268 non-null   object
# dtypes: float64(3), int64(1), object(11)
# memory usage: 617.5+ KB

# %%
lista = ['Operator','nFlight','Route','Type','Registration','cn/In',
         'Time']
air2.Location.fillna('Unknown', inplace = True)

# %% [markdown]
# # Análisis previo 2º dataset Kaggle

# %%
air2 = pd.read_csv('data/aircrash1908-2008.csv', encoding = 'latin1')

# %%
air2.head()
# Out:
#          Date              Time                            Location  \
# 0  09/17/1908  09/17/1908 17:18                 Fort Myer, Virginia
# 1  07/12/1912  07/12/1912 06:30             AtlantiCity, New Jersey
# 2  08/06/1913  08/06/1913 00:00  Victoria, British Columbia, Canada
# 3  09/09/1913  09/09/1913 18:30                  Over the North Sea
# 4  10/17/1913  10/17/1913 10:30          Near Johannisthal, Germany
#
#                  Operator Flight #          Route                    Type  \
# 0    Military - U.S. Army      NaN  Demonstration        Wright Flyer III
# 1    Military - U.S. Navy      NaN    Test flight               Dirigible
# 2                 Private        -            NaN        Curtiss seaplane
# 3  Military - German Navy      NaN            NaN  Zeppelin L-1 (airship)
# 4  Military - German Navy      NaN            NaN  Zeppelin L-2 (airship)
#
#   Registration cn/In  Aboard  Fatalities  Ground  \
# 0          NaN     1     2.0         1.0     0.0
# 1          NaN   NaN     5.0         5.0     0.0
# 2          NaN   NaN     1.0         1.0     0.0
# 3          NaN   NaN    20.0        14.0     0.0
# 4          NaN   NaN    30.0        30.0     0.0
#
#                                              Summary
# 0  During a demonstration flight, a U.S. Army fly...
# 1  First U.S. dirigible Akron exploded just offsh...
# 2  The first fatal airplane accident in Canada oc...
# 3  The airship flew into a thunderstorm and encou...
# 4  Hydrogen gas which was being vented was sucked...

# %%
air2.shape
# Out:
# (5268, 13)

# %%
air.shape
# Out:
# (5268, 13)

# %%
air2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5268 entries, 0 to 5267
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          5268 non-null   object
#  1   Time          5268 non-null   object
#  2   Location      5248 non-null   object
#  3   Operator      5250 non-null   object
#  4   Flight #      1069 non-null   object
#  5   Route         3562 non-null   object
#  6   Type          5241 non-null   object
#  7   Registration  4933 non-null   object
#  8   cn/In         4040 non-null   object
#  9   Aboard        5246 non-null   float64
#  10  Fatalities    5256 non-null   float64
#  11  Ground        5246 non-null   float64
#  12  Summary       4878 non-null   object
# dtypes: float64(3), object(10)
# memory usage: 535.2+ KB

# %%
air.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5268 entries, 0 to 5267
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          5268 non-null   object
#  1   Time          3049 non-null   object
#  2   Location      5248 non-null   object
#  3   Operator      5250 non-null   object
#  4   Flight #      1069 non-null   object
#  5   Route         3562 non-null   object
#  6   Type          5241 non-null   object
#  7   Registration  4933 non-null   object
#  8   cn/In         4040 non-null   object
#  9   Aboard        5246 non-null   float64
#  10  Fatalities    5256 non-null   float64
#  11  Ground        5246 non-null   float64
#  12  Summary       4878 non-null   object
# dtypes: float64(3), object(10)
# memory usage: 535.2+ KB

# %% [markdown]
# # Análisis previo dataset Bancomundial.org
# nota: sacarlo en inglés (cantidad de vuelos por país y año)

# %%
bmun = pd.read_csv('data/bancomundial_org.csv', error_bad_lines=False,encoding = 'latin1')
# Out:
# b'Skipping line 5: expected 3 fields, saw 66\nSkipping line 6: expected 3 fields, saw 66\nSkipping line 7: expected 3 fields, saw 66\nSkipping line 8: expected 3 fields, saw 66\nSkipping line 9: expected 3 fields, saw 66\nSkipping line 10: expected 3 fields, saw 66\nSkipping line 11: expected 3 fields, saw 66\nSkipping line 12: expected 3 fields, saw 66\nSkipping line 13: expected 3 fields, saw 66\nSkipping line 14: expected 3 fields, saw 66\nSkipping line 15: expected 3 fields, saw 66\nSkipping line 16: expected 3 fields, saw 66\nSkipping line 17: expected 3 fields, saw 66\nSkipping line 18: expected 3 fields, saw 66\nSkipping line 19: expected 3 fields, saw 66\nSkipping line 20: expected 3 fields, saw 66\nSkipping line 21: expected 3 fields, saw 66\nSkipping line 22: expected 3 fields, saw 66\nSkipping line 23: expected 3 fields, saw 66\nSkipping line 24: expected 3 fields, saw 66\nSkipping line 25: expected 3 fields, saw 66\nSkipping line 26: expected 3 fields, saw 66\nSkipping line 27: expected 3 fields, saw 66\nSkipping line 28: expected 3 fields, saw 66\nSkipping line 29: expected 3 fields, saw 66\nSkipping line 30: expected 3 fields, saw 66\nSkipping line 31: expected 3 fields, saw 66\nSkipping line 32: expected 3 fields, saw 66\nSkipping line 33: expected 3 fields, saw 66\nSkipping line 34: expected 3 fields, saw 66\nSkipping line 35: expected 3 fields, saw 66\nSkipping line 36: expected 3 fields, saw 66\nSkipping line 37: expected 3 fields, saw 66\nSkipping line 38: expected 3 fields, saw 66\nSkipping line 39: expected 3 fields, saw 66\nSkipping line 40: expected 3 fields, saw 66\nSkipping line 41: expected 3 fields, saw 66\nSkipping line 42: expected 3 fields, saw 66\nSkipping line 43: expected 3 fields, saw 66\nSkipping line 44: expected 3 fields, saw 66\nSkipping line 45: expected 3 fields, saw 66\nSkipping line 46: expected 3 fields, saw 66\nSkipping line 47: expected 3 fields, saw 66\nSkipping line 48: expected 3 fields, saw 66\nSkipping line 49: expected 3 fields, saw 66\nSkipping line 50: expected 3 fields, saw 66\nSkipping line 51: expected 3 fields, saw 66\nSkipping line 52: expected 3 fields, saw 66\nSkipping line 53: expected 3 fields, saw 66\nSkipping line 54: expected 3 fields, saw 66\nSkipping line 55: expected 3 fields, saw 66\nSkipping line 56: expected 3 fields, saw 66\nSkipping line 57: expected 3 fields, saw 66\nSkipping line 58: expected 3 fields, saw 66\nSkipping line 59: expected 3 fields, saw 66\nSkipping line 60: expected 3 fields, saw 66\nSkipping line 61: expected 3 fields, saw 66\nSkipping line 62: expected 3 fields, saw 66\nSkipping line 63: expected 3 fields, saw 66\nSkipping line 64: expected 3 fields, saw 66\nSkipping line 65: expected 3 fields, saw 66\nSkipping line 66: expected 3 fields, saw 66\nSkipping line 67: expected 3 fields, saw 66\nSkipping line 68: expected 3 fields, saw 66\nSkipping line 69: expected 3 fields, saw 66\nSkipping line 70: expected 3 fields, saw 66\nSkipping line 71: expected 3 fields, saw 66\nSkipping line 72: expected 3 fields, saw 66\nSkipping line 73: expected 3 fields, saw 66\nSkipping line 74: expected 3 fields, saw 66\nSkipping line 75: expected 3 fields, saw 66\nSkipping line 76: expected 3 fields, saw 66\nSkipping line 77: expected 3 fields, saw 66\nSkipping line 78: expected 3 fields, saw 66\nSkipping line 79: expected 3 fields, saw 66\nSkipping line 80: expected 3 fields, saw 66\nSkipping line 81: expected 3 fields, saw 66\nSkipping line 82: expected 3 fields, saw 66\nSkipping line 83: expected 3 fields, saw 66\nSkipping line 84: expected 3 fields, saw 66\nSkipping line 85: expected 3 fields, saw 66\nSkipping line 86: expected 3 fields, saw 66\nSkipping line 87: expected 3 fields, saw 66\nSkipping line 88: expected 3 fields, saw 66\nSkipping line 89: expected 3 fields, saw 66\nSkipping line 90: expected 3 fields, saw 66\nSkipping line 91: expected 3 fields, saw 66\nSkipping line 92: expected 3 fields, saw 66\nSkipping line 93: expected 3 fields, saw 66 ...

# %%
bmun.head()
# Out:
#     ï»¿"Data Source" Indicadores del desarrollo mundial  Unnamed: 2
# 0  Last Updated Date                         2021-03-19         NaN

# %% [markdown]
# # Test Scrapping

# %%
url = 'http://www.planecrashinfo.com/CATATC.htm'

tablas = pd.read_html(url)

tablas[0]
# Out:
#                              0                           1  \
# 0   Air Traffic Control Errors  Air Traffic Control Errors
# 1                    6/13/1947          Leesburg, Virginia
# 2                   05/22/1948          Khabarovsk, Russia
# 3                   11/01/1949         Arlington, Virginia
# 4                   10/05/1952           Skvoritsy, Russia
# 5                   04/14/1958       Castel de Fels, Spain
# 6                   07/21/1961              Shemya, Alaska
# 7                   02/08/1965          New York, New York
# 8                   03/09/1967                Urbana, Ohio
# 9                   03/05/1969       San Juan, Puerto Rico
# 10                  09/09/1969           Fairland, Indiana
# 11                  02/06/1970             Samarkand, USSR
# 12                  09/17/1971         Balkan Bulgarian AL
# 13                  12/04/1971     Raleigh, North Carolina
# 14                  01/04/1972           Plovdiv, Bulgaria
# 15                  05/04/1972              Bratsk, Russia
# 16                  12/20/1972           Chicago, Illinois
# 17                  07/31/1973       Boston, Massachusetts
# 18                  12/01/1974        Berryville, Virginia
# 19                  03/20/1975        Quilcene, Washington
# 20                  12/04/1974             Irkutsk, Russia
# 21                  09/09/1976               Adler, Russia
# 22                  09/10/1976        Hrvatska, Yugoslavia
# 23                  02/11/1978               Cranbrook, BC
# 24                  08/11/1979      Dneprodzerzhinsk, USSR
# 25                  09/14/1979              Sarroch, Italy
# 26                  08/24/1981           Zavitinsk, Russia
# 27                  04/11/1983           Leninakan, Russia
# 28                  04/19/1983           Keninakan, Russia
# 29                  03/06/1987                    Aeroflot
# 30                  02/18/1989      Kuala Lumpur, Malaysia
# 31                  02/01/1991     Los Angeles, California
# 32                  01/20/1992          Strasbourg, France
# 33                  09/22/1995            Ancorage, Alaska
# 34                  11/07/1996              Lagos, Nigeria
# 35                  09/26/1997       Buah Nabar, Indonesia
# 36                  11/12/1999            Pristina, Kosovo
# 37                  10/25/2000              Batumi,Georgia
# 38                  07/01/2002         Uberlinger, Germany
# 39                  03/31/1995          Balotesti, Romania
# 40                  09/04/2000   Near Burketown, Australia
# 41                  08/14/2005         Grammatikos, Greece
#
#                                           2  \
# 0                Air Traffic Control Errors
# 1                           Pennsylvania AL
# 2                                  Aeroflot
# 3                         Eastern Air Lines
# 4                                  Aeroflot
# 5                                    Aviaco
# 6                                 Alaska AL
# 7                                Eastern AL
# 8                      Trans World Airlines
# 9                                   Prinair
# 10                             Allegheny AL
# 11                                 Aeroflot
# 12                  Rila mountain, Bulgaria
# 13                               Eastern AL
# 14                      Balkan Bulgarian AL
# 15                                 Aeroflot
# 16                      Delta/North Central
# 17                          Delta Air Lines
# 18                     Trans World Airlines
# 19                           U.S. Air Force
# 20                                 Aeroflot
# 21                      Aeroflot / Aeroflot
# 22  Inex Adria Aviopromet / British Airways
# 23                       Pacific Western AL
# 24                                 Aeroflot
# 25                 Aero Transporti Italiani
# 26                        Russian Air Force
# 27                                 Aeroflot
# 28                                 Aeroflot
# 29                       Almaty, Kazakhstan
# 30                          Flying Tiger AL
# 31                            USAir/Skywest
# 32                                Air Inter
# 33                           U.S. Air Force
# 34                      Aviation Dev. Corp.
# 35                     Garuda Indonesian AL
# 36                               UN Charter
# 37                        Russian Air Force
# 38                      Bashkirian AL / DHL
# 39                      Trans. Aeriene Rom.
# 40                              Central Air
# 41                           Helios Airways
#
#                                                     3
# 0                          Air Traffic Control Errors
# 1   A contributing cause was the faulty clearance ...
# 2                                          ATC error.
# 3                                          ATC error.
# 4   Midair collision with a TC-62 aircraft. ATC er...
# 5   Another aircraft was permitted to takeoff with...
# 6   Lack of guidance from air traffic controller d...
# 7   Placement of the two aircraft on a near head o...
# 8   ATC systems inadequate to separate controlled ...
# 9   A trainee vectored the aircraft into mountaino...
# 10  Inadequate VFR separation and deficiencies in ...
# 11  Misidentification of aircraft by the ATC causi...
# 12  The ATC confused the aircraft with another Tur...
# 13  Inadequacy of ATC facilities and services in t...
# 14  While on approach, the aircraft flew into a mo...
# 15  ATC error. Current weather was not passed on t...
# 16   The ATC gave ambiguous instructions to the crew.
# 17  Poor positioning of the aircraft for an approa...
# 18                 Lack of clarity in ATC procedures.
# 19  Faulty clearance by the ATC after misidentifyi...
# 20  ATC error, negligence in operations. Midair co...
# 21                     Violation of separation rules.
# 22  ATC error, negligence in operations. Midair co...
# 23  Estimated time of arrival given by Calgary ATC...
# 24  Separation error by the ATC causing a midair c...
# 25                         Inadequate ATC assistance.
# 26  Poor communication between civilian and milita...
# 27  ATC procedural error in not identifying the pl...
# 28  ATC procedural error in not identifying the pl...
# 29  The ATC didn't monitor the plane for at least ...
# 30  Non-standard phraseology used by Kuala Lumpur ...
# 31  ATC cleared a plane to land while the runway w...
# 32  The plane was slightly off course due to ATC e...
# 33          ATC did not worn about birds in the area.
# 34  The controller thought he had cleared to aircr...
# 35  ATC error in directing the plane in the wrong ...
# 36             Improper tracking by the military ATC.
# 37                                         ATC error.
# 38  Conflicting information give to pilot by ATC a...
# 39  The captain was incapacitated shortly after ta...
# 40  Incapacitation of the captain due to depressur...
# 41  Pressurization failure incapacitated the entir...

# %%
url = 'https://www.airfleets.es/crash/crash_year_1970.htm'

req = urllib.request.Request(
    url, 
    data=None, 
    headers={
        'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.47 Safari/537.36'
    })
html =urllib.request.urlopen(req)
soup = BeautifulSoup(html)

#método para etiquetas y atributos

#tag = soup.find_all('tr',class_ ='textenu')
#listacampos = []
#
#texto = str(tag[0])
#texto = texto.replace('<tr bgcolor="#75AADB" class="textenu">','').replace('<td width="20%">','')\
#              .replace('<td width="45%">','').replace('<td width="25%">','').replace('<td width="10%">','')\
#              .replace('</td>','').replace('\n</tr>','')
##Relleno una lista con el nombre de los campos
#listacampos = list(texto.split(sep='\n'))
#listacampos = listacampos[1:]
#listacampos

#lines = soup.find_all('tr',class_ ='trtab')
#print(len(lines))
#lines
#data = soup.find_all('td',class_ ='tdtexten')
b = soup('b')
len(b)
# Out:
# 6

# %%
#evaluar si es mejor usar lines o data, lines tiene un elemento por registro 
#lines es etiqueta 'tr',class_ ='trtab': cada 'tr' es un registro
print(len(lines))
lines
# Out:
# 2
# [<tr class="trtab">
#  <td class="tdtexten" valign="top" width="20%"><b><a class="lien" href="../crash/crash_report_United Airlines_N9005U.htm">19/07/1970</a></b></td>
#  <td class="tdtexten" width="45%"><b>United Airlines</b> N9005U (MSN 19043)<br/><br/>Philadelphia, USA</td>
#  <td class="tdtexten" valign="top" width="25%">Boeing 737</td>
#  <td class="tdtexten" valign="top" width="10%">0</td>
#  </tr>,
#  <tr class="trtab">
#  <td class="tdtexten" valign="top" width="20%"><b><a class="lien" href="../crash/crash_report_Pan Am_N752PA.htm">06/09/1970</a></b></td>
#  <td class="tdtexten" width="45%"><b>Pan Am</b> N752PA (MSN 19656)<br/><br/>Cairo, Egypt</td>
#  <td class="tdtexten" valign="top" width="25%">Boeing 747</td>
#  <td class="tdtexten" valign="top" width="10%">0</td>
#  </tr>]

# %%
'''
data:
En las etiquetas 'td',class_ ='tdtexten', están los datos de la tabla,
cada 4 elementos = 1 registro. Dividido de la siguiente forma:

1er elemento: contiene la fecha del accidente
2º  elemento: esta línea contiene dos elementos; 1:compañía, 2: ciudad/país
3er elemento: contiene marca y modelo de avión
4º  elemento: contiene número de víctimas

De esta forma se puede hacer una tabla con 6 variables:
(fecha,compañía, ciudad, país, modelo y nº de víctimas)

si el length de este objeto define el número de registros (len/4 = registros)

'''
print(len(data))
for i in range(len(data)):
    print(data[i],'\n')
# Out:
# 8
# <td class="tdtexten" valign="top" width="20%"><b><a class="lien" href="../crash/crash_report_United Airlines_N9005U.htm">19/07/1970</a></b></td>
#
# <td class="tdtexten" width="45%"><b>United Airlines</b> N9005U (MSN 19043)<br/><br/>Philadelphia, USA</td>
#
# <td class="tdtexten" valign="top" width="25%">Boeing 737</td>
#
# <td class="tdtexten" valign="top" width="10%">0</td>
#
# <td class="tdtexten" valign="top" width="20%"><b><a class="lien" href="../crash/crash_report_Pan Am_N752PA.htm">06/09/1970</a></b></td>
#
# <td class="tdtexten" width="45%"><b>Pan Am</b> N752PA (MSN 19656)<br/><br/>Cairo, Egypt</td>
#
# <td class="tdtexten" valign="top" width="25%">Boeing 747</td>
#
# <td class="tdtexten" valign="top" width="10%">0</td>
